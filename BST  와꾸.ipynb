# %%
from binary_tree import *

# %%
class Bst(BinaryTree):
    
    def insert(self, data):
        
        
        
        #BST 가 비었을때
        
        
        
        #무한루프 
        
        while True:
            
            #값이 작을때 비어있지 않으면 왼쪽으로가고 비어있으면 값을 넣어라
            
            
            #값이 클때는 반대로
        
    def search(self, target):
        
        
        
        return cur
    
    def remove_leaf(self, parent, del_node):
        #예외처리 루트노드가 지우려는 노드일때
        
        if
            return del_node
        
        #P의 왼쪽이 D면 P왼쪽을 None으로
            elif
            
            
            else:
        
            return del_node
        
        
    
    def remove_one_child(self, parent, del_node):
        #예외처리 루트 노드가 지우려는 노드일때
        if 
            #왼쪽에 자식노드가 있다면 루트를 자식으로 옮김
            if 
            
            #오른쪽 '
            else:
        
    def remove_two_child(self e/, del_node):
    
    
    
    def remove(self, target):
        del_parent = 
        del_node = 
        
        while True:
            #타겟이 없다면 
            if
                return None
            #타겟이랑  delnode가 같으면 
            if
                break
            #타겟이 작다면 왼쪽으로   
            elif
            #타겟이 크다면 오른쪽
            else:
                
        #리프 or 자식 하나 or 자식 2개
        if
        
        
        elif
        
        
        else:
