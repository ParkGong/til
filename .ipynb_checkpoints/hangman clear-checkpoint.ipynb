# %%
# Problem Set 2, hangman.py
# Name: 
# Collaborators:
# Time spent:

# Hangman Game
# -----------------------------------
# Helper code
# You don't need to understand this helper code,
# but you will have to know how to use the functions
# (so be sure to read the docstrings!)
import random
import string

WORDLIST_FILENAME = "words.txt"


def load_words():
    """
    Returns a list of valid words. Words are strings of lowercase letters.
    
    Depending on the size of the word list, this function may
    take a while to finish.
    """
    print("Loading word list from file...")
    # inFile: file
    inFile = open(WORDLIST_FILENAME, 'r')
    # line: string
    line = inFile.readline()
    # wordlist: list of strings
    wordlist = line.split()
    print("  ", len(wordlist), "words loaded.")
    return wordlist



def choose_word(wordlist):
    """
    wordlist (list): list of words (strings)
    
    Returns a word from wordlist at random
    """
    return random.choice(wordlist)

# end of helper code

# -----------------------------------

# Load the list of words into the variable wordlist
# so that it can be accessed from anywhere in the program
wordlist = load_words()


def is_word_guessed(secret_word, letters_guessed):

    
    '''
    secret_word: string, the word the user is guessing; assumes all letters are
      lowercase
    letters_guessed: list (of letters), which letters have been guessed so far;
      assumes that all letters are lowercase
    returns: boolean, True if all the letters of secret_word are in letters_guessed;
      False otherwise
    '''
    # FILL IN YOUR CODE HERE AND DELETE "pass"
    new_secret_word = set(secret_word)
    new_guessed_word = set(letters_guessed)
    return new_secret_word == new_guessed_word



def get_guessed_word(secret_word, letters_guessed):
    '''
    secret_word: string, the word the user is guessing
    letters_guessed: list (of letters), which letters have been guessed so far
    returns: string, comprised of letters, underscores (_), and spaces that represents
      which letters in secret_word have been guessed so far.
    '''
    word = ""
    
    for i in range(len(secret_word)):
        if secret_word[i] in letters_guessed:
            word += secret_word[i]
        else:
            word += "_ "
    return word

def get_available_letters(letters_guessed):
    '''
    letters_guessed: list (of letters), which letters have been guessed so far
    returns: string (of letters), comprised of letters that represents which letters have not
      yet been guessed.
    '''
    # FILL IN YOUR CODE HERE AND DELETE "pass"
    all_alpha = "abcdefghijklmnopqrstuvwxyz"
    res = ""
    for i in range(len(all_alpha)):
        if all_alpha[i] in letters_guessed:
            res += ""
        else:
            res += all_alpha[i]
    return res


if __name__ == "__main__":
    # pass
    
    # To test part 2, comment out the pass line above and
    # uncomment the following two lines.
    
    secret_word = choose_word(wordlist)
    #hangman(secret_word)
# Out:
# Loading word list from file...
#    55900 words loaded.

# %%
trial = 6
words = []
used_words = []

while (trial <=6 and trial>0) and is_word_guessed(secret_word,words) == False:

    
    
    #print("Welcome to the game Hangman!\nI am thinking of a word that {} letters long.\n{} Guess it".format(len(secret_word),trial))
    user_guessed = input("알파벳을 입력하세요")     
    get_available_letters(user_guessed)
    print(user_guessed)

          

    if user_guessed in secret_word:
        words.append(user_guessed)
        used_words.append(user_guessed)
        print("Good guess : ")
        get_guessed_word(secret_word, words)
        print(get_guessed_word(secret_word,words))
        print("\nYou have {} guessess left".format(trial))
        print(get_available_letters(used_words))
          
    elif user_guessed not in secret_word:
        trial = trial -1
        
        used_words.append(user_guessed)
        
        print("Oops! That letter is not in my word")
        print("\nYou have {} guessess left".format(trial))
        get_guessed_word(secret_word,used_words)
        print(get_guessed_word(secret_word,used_words))
        print(get_available_letters(used_words))
# Out:
# 알파벳을 입력하세요a
# a
# Oops! That letter is not in my word
#
# You have 5 guessess left
# _ _ _ _ _
# bcdefghijklmnopqrstuvwxyz
# 알파벳을 입력하세요b
# b
# Oops! That letter is not in my word
#
# You have 4 guessess left
# _ _ _ _ _
# cdefghijklmnopqrstuvwxyz
# 알파벳을 입력하세요c
# c
# Oops! That letter is not in my word
#
# You have 3 guessess left
# _ _ _ _ _
# defghijklmnopqrstuvwxyz
# 알파벳을 입력하세요
#
# Good guess :
# _ _ _ _ _
#
# You have 3 guessess left
# defghijklmnopqrstuvwxyz
# 알파벳을 입력하세요e
# e
# Oops! That letter is not in my word
#
# You have 2 guessess left
# _ _ _ _ _
# dfghijklmnopqrstuvwxyz
# 알파벳을 입력하세요d
# d
# Oops! That letter is not in my word
#
# You have 1 guessess left
# _ _ _ _ _
# fghijklmnopqrstuvwxyz
# 알파벳을 입력하세요w
# w
# Good guess :
# w_ _ _ _
#
# You have 1 guessess left
# fghijklmnopqrstuvxyz
# 알파벳을 입력하세요f
# f
# Oops! That letter is not in my word
#
# You have 0 guessess left
# w_ _ _ _
# ghijklmnopqrstuvxyz
